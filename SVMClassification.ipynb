# %% [markdown]
# # Use SVM to attempt to classify currency pairs based on historic OfferCreate data

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('Ledger_Account_Currency_Pairs_2024-12-04.csv')

# %%
df.head()
# Out:
#    Ledger_Number               Ledger_Date  \
# 0       67399995  2021-10-31T20:44:10.000Z
# 1       67399995  2021-10-31T20:44:10.000Z
# 2       67399995  2021-10-31T20:44:10.000Z
# 3       67399995  2021-10-31T20:44:10.000Z
# 4       67399995  2021-10-31T20:44:10.000Z
#
#                            Account_ID  \
# 0  r4AZpDKVoBxVcYUJCWMcqZzyWsHTteC4ZE
# 1  r4dgY6Mzob3NVq8CFYdEiPnXKboRScsXRu
# 2  rDogkw75XgwYfAcX4om7jYUgZyXvQrkh6i
# 3  rDogkw75XgwYfAcX4om7jYUgZyXvQrkh6i
# 4   rFSEzZAJUooos1DzxzDiFGaY7SUZkyrZc
#
#                          Gets_Currency_Code  \
# 0                                       XRP
# 1                                       CNY
# 2  5852646F67650000000000000000000000000000
# 3                                       XRP
# 4                                       FSE
#
#                          Pays_Currency_Code  Row_Count  Transaction_Fee_med  \
# 0                                       CNY          8                 12.0
# ...

# %% [markdown]
# ### Eliminate Ledger_Number, atp just a muddy Ledger_Date substitute

# %%
df = df.drop(columns=['Ledger_Number'])

# %% [markdown]
# ### Must scale Numeric Data

# %%
scaler = MinMaxScaler()
